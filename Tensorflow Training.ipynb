# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /Users/kosangwon/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
import numpy as np
from pandas.io.parsers import read_csv

model = tf.global_variables_initializer();



data = read_csv('price data.csv', sep=',')



xy = np.array(data, dtype=np.float32)



# 4개의 변인을 입력을 받습니다.

x_data = xy[:, 1:-1]



# 가격 값을 입력 받습니다.

y_data = xy[:, [-1]]



# 플레이스 홀더를 설정합니다.

X = tf.placeholder(tf.float32, shape=[None, 4])

Y = tf.placeholder(tf.float32, shape=[None, 1])



W = tf.Variable(tf.random_normal([4, 1]), name="weight")

b = tf.Variable(tf.random_normal([1]), name="bias")



# 가설을 설정합니다.

hypothesis = tf.matmul(X, W) + b



# 비용 함수를 설정합니다.

cost = tf.reduce_mean(tf.square(hypothesis - Y))



# 최적화 함수를 설정합니다.

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)

train = optimizer.minimize(cost)



# 세션을 생성합니다.

sess = tf.Session()



# 글로벌 변수를 초기화합니다.

sess.run(tf.global_variables_initializer())



# 학습을 수행합니다.

for step in range(100001):

    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})

    if step % 500 == 0:

        print("#", step, " 손실 비용: ", cost_)

        print("- 배추 가격: ", hypo_[0])



# 학습된 모델을 저장합니다.

saver = tf.train.Saver()

save_path = saver.save(sess, "./saved.cpkt")

print('학습된 모델을 저장했습니다.')
# Out:
# # 0  손실 비용:  12679851.0
# - 배추 가격:  [17.606636]
# # 500  손실 비용:  4178502.5
# - 배추 가격:  [-265.4191]
# # 1000  손실 비용:  3775556.2
# - 배추 가격:  [43.164215]
# # 1500  손실 비용:  3460728.2
# - 배추 가격:  [324.3839]
# # 2000  손실 비용:  3213043.2
# - 배추 가격:  [574.24554]
# # 2500  손실 비용:  3017732.2
# - 배추 가격:  [796.23834]
# # 3000  손실 비용:  2863485.0
# - 배추 가격:  [993.5229]
# # 3500  손실 비용:  2741544.8
# - 배추 가격:  [1168.8865]
# # 4000  손실 비용:  2645074.8
# - 배추 가격:  [1324.7926]
# # 4500  손실 비용:  2568715.2
# - 배추 가격:  [1463.4192]
# # 5000  손실 비용:  2508246.8
# - 배추 가격:  [1586.6938]
# # 5500  손실 비용:  2460342.2
# - 배추 가격:  [1696.328]
# # 6000  손실 비용:  2422376.0
# - 배추 가격:  [1793.8376]
# # 6500  손실 비용:  2392271.8
# - 배추 가격:  [1880.5669]
# # 7000  손실 비용:  2368388.0
# - 배추 가격:  [1957.7136]
# # 7500  손실 비용:  2349426.2
# - 배추 가격:  [2026.3381]
# # 8000  손실 비용:  2334360.0
# - 배추 가격:  [2087.384]
# # 8500  손실 비용:  2322376.8
# - 배추 가격:  [2141.6902]
# # 9000  손실 비용:  2312832.8
# - 배추 가격:  [2190.002]
# # 9500  손실 비용:  2305220.0
# - 배추 가격:  [2232.981]
# # 10000  손실 비용:  2299134.8
# - 배추 가격:  [2271.218]
# # 10500  손실 비용:  2294259.0
# - 배추 가격:  [2305.2356]
# # 11000  손실 비용:  2290341.0
# - 배추 가격:  [2335.501]
# # 11500  손실 비용:  2287180.0
# - 배추 가격:  [2362.4272]
# # 12000  손실 비용:  2284619.2
# - 배추 가격:  [2386.384]
# # 12500  손실 비용:  2282532.5
# - 배추 가격:  [2407.6992]
# # 13000  손실 비용:  2280821.5
# - 배추 가격:  [2426.6653]
# # 13500  손실 비용:  2279408.0
# - 배추 가격:  [2443.5403]
# # 14000  손실 비용:  2278230.2
# - 배추 가격:  [2458.5544]
# # 14500  손실 비용:  2277238.2
# - 배추 가격:  [2471.9143]
# # 15000  손실 비용:  2276393.8
# - 배추 가격:  [2483.803]
# # 15500  손실 비용:  2275666.0
# - 배추 가격:  [2494.3816]
# # 16000  손실 비용:  2275030.8
# - 배추 가격:  [2503.7961]
# # 16500  손실 비용:  2274468.8
# - 배추 가격:  [2512.1733]
# # 17000  손실 비용:  2273965.0
# - 배추 가격:  [2519.6292]
# # 17500  손실 비용:  2273507.0
# - 배추 가격:  [2526.2642]
# # 18000  손실 비용:  2273085.5
# - 배추 가격:  [2532.1697]
# # 18500  손실 비용:  2272692.8
# - 배추 가격:  [2537.427]
# # 19000  손실 비용:  2272323.0
# - 배추 가격:  [2542.1057]
# # 19500  손실 비용:  2271971.5
# - 배추 가격:  [2546.2705]
# # 20000  손실 비용:  2271633.8
# - 배추 가격:  [2549.9805]
# # 20500  손실 비용:  2271308.2
# - 배추 가격:  [2553.2827]
# # 21000  손실 비용:  2270991.5
# - 배추 가격:  [2556.221]
# # 21500  손실 비용:  2270682.0
# - 배추 가격:  [2558.8384]
# # 22000  손실 비용:  2270378.2
# - 배추 가격:  [2561.1702]
# # 22500  손실 비용:  2270079.2
# - 배추 가격:  [2563.2463]
# # 23000  손실 비용:  2269783.5
# - 배추 가격:  [2565.098]
# # 23500  손실 비용:  2269491.2
# - 배추 가격:  [2566.7456]
# # 24000  손실 비용:  2269201.2
# - 배추 가격:  [2568.2126]
# # 24500  손실 비용:  2268913.0
# - 배추 가격:  [2569.5198]
# # 25000  손실 비용:  2268626.5
# - 배추 가격:  [2570.6882]
# # 25500  손실 비용:  2268341.2
# - 배추 가격:  [2571.729]
# # 26000  손실 비용:  2268056.5
# - 배추 가격:  [2572.6611]
# # 26500  손실 비용:  2267774.0
# - 배추 가격:  [2573.4932]
# # 27000  손실 비용:  2267491.5
# - 배추 가격:  [2574.227]
# # 27500  손실 비용:  2267209.0
# - 배추 가격:  [2574.8765]
# # 28000  손실 비용:  2266927.8
# - 배추 가격:  [2575.478]
# # 28500  손실 비용:  2266646.8
# - 배추 가격:  [2576.0073]
# # 29000  손실 비용:  2266366.5
# - 배추 가격:  [2576.4912]
# # 29500  손실 비용:  2266086.0
# - 배추 가격:  [2576.9172]
# # 30000  손실 비용:  2265806.0
# - 배추 가격:  [2577.2888]
# # 30500  손실 비용:  2265526.5
# - 배추 가격:  [2577.6284]
# # 31000  손실 비용:  2265247.8
# - 배추 가격:  [2577.954]
# # 31500  손실 비용:  2264969.0
# - 배추 가격:  [2578.1987]
# # 32000  손실 비용:  2264689.8
# - 배추 가격:  [2578.441]
# # 32500  손실 비용:  2264410.8
# - 배추 가격:  [2578.6821]
# # 33000  손실 비용:  2264132.8
# - 배추 가격:  [2578.9148]
# # 33500  손실 비용:  2263854.0
# - 배추 가격:  [2579.101]
# # 34000  손실 비용:  2263575.8
# - 배추 가격:  [2579.2356]
# # 34500  손실 비용:  2263298.8
# - 배추 가격:  [2579.3645]
# # 35000  손실 비용:  2263021.5
# - 배추 가격:  [2579.4927]
# # 35500  손실 비용:  2262745.0
# - 배추 가격:  [2579.6206]
# # 36000  손실 비용:  2262468.2
# - 배추 가격:  [2579.7485]
# # 36500  손실 비용:  2262191.2
# - 배추 가격:  [2579.8762]
# # 37000  손실 비용:  2261915.0
# - 배추 가격:  [2580.004]
# # 37500  손실 비용:  2261638.2
# - 배추 가격:  [2580.129]
# # 38000  손실 비용:  2261362.2
# - 배추 가격:  [2580.2493]
# # 38500  손실 비용:  2261085.8
# - 배추 가격:  [2580.3015]
# # 39000  손실 비용:  2260809.5
# - 배추 가격:  [2580.3389]
# # 39500  손실 비용:  2260533.2
# - 배추 가격:  [2580.3765]
# # 40000  손실 비용:  2260258.2
# - 배추 가격:  [2580.413]
# # 40500  손실 비용:  2259983.5
# - 배추 가격:  [2580.4475]
# # 41000  손실 비용:  2259708.8
# - 배추 가격:  [2580.4795]
# # 41500  손실 비용:  2259434.2
# - 배추 가격:  [2580.5127]
# # 42000  손실 비용:  2259160.0
# - 배추 가격:  [2580.5457]
# # 42500  손실 비용:  2258885.8
# - 배추 가격:  [2580.5789]
# # 43000  손실 비용:  2258612.0
# - 배추 가격:  [2580.612]
# # 43500  손실 비용:  2258338.0
# - 배추 가격:  [2580.6455]
# # 44000  손실 비용:  2258064.0
# - 배추 가격:  [2580.679]
# # 44500  손실 비용:  2257790.5
# - 배추 가격:  [2580.7124]
# # 45000  손실 비용:  2257517.0
# - 배추 가격:  [2580.746]
# # 45500  손실 비용:  2257243.8
# - 배추 가격:  [2580.7793]
# # 46000  손실 비용:  2256970.2
# - 배추 가격:  [2580.8132]
# # 46500  손실 비용:  2256697.2
# - 배추 가격:  [2580.8474]
# # 47000  손실 비용:  2256424.2
# - 배추 가격:  [2580.8833]
# # 47500  손실 비용:  2256151.2
# - 배추 가격:  [2580.9202]
# # 48000  손실 비용:  2255880.0
# - 배추 가격:  [2580.9543]
# # 48500  손실 비용:  2255608.8
# - 배추 가격:  [2580.9897]
# # 49000  손실 비용:  2255337.5
# - 배추 가격:  [2581.0276]
# # 49500  손실 비용:  2255066.2
# - 배추 가격:  [2581.0662]
# # 50000  손실 비용:  2254795.0
# - 배추 가격:  [2581.1082]
# # 50500  손실 비용:  2254524.2
# - 배추 가격:  [2581.1501]
# # 51000  손실 비용:  2254253.8
# - 배추 가격:  [2581.192]
# # 51500  손실 비용:  2253983.2
# - 배추 가격:  [2581.2378]
# # 52000  손실 비용:  2253712.8
# - 배추 가격:  [2581.284]
# # 52500  손실 비용:  2253442.2
# - 배추 가격:  [2581.33]
# # 53000  손실 비용:  2253171.8
# - 배추 가격:  [2581.3757]
# # 53500  손실 비용:  2252901.8
# - 배추 가격:  [2581.425]
# # 54000  손실 비용:  2252632.0
# - 배추 가격:  [2581.475]
# # 54500  손실 비용:  2252362.0
# - 배추 가격:  [2581.5254]
# # 55000  손실 비용:  2252092.8
# - 배추 가격:  [2581.572]
# # 55500  손실 비용:  2251824.5
# - 배추 가격:  [2581.6165]
# # 56000  손실 비용:  2251555.8
# - 배추 가격:  [2581.6638]
# # 56500  손실 비용:  2251287.8
# - 배추 가격:  [2581.712]
# # 57000  손실 비용:  2251019.2
# - 배추 가격:  [2581.76]
# # 57500  손실 비용:  2250751.0
# - 배추 가격:  [2581.8083]
# # 58000  손실 비용:  2250483.0
# - 배추 가격:  [2581.8564]
# # 58500  손실 비용:  2250215.2
# - 배추 가격:  [2581.905]
# # 59000  손실 비용:  2249948.5
# - 배추 가격:  [2581.9487]
# # 59500  손실 비용:  2249682.0
# - 배추 가격:  [2581.9934]
# # 60000  손실 비용:  2249415.8
# - 배추 가격:  [2582.044]
# # 60500  손실 비용:  2249149.5
# - 배추 가격:  [2582.0945]
# # 61000  손실 비용:  2248883.2
# - 배추 가격:  [2582.1377]
# # 61500  손실 비용:  2248617.5
# - 배추 가격:  [2582.1714]
# # 62000  손실 비용:  2248351.2
# - 배추 가격:  [2582.2046]
# # 62500  손실 비용:  2248085.2
# - 배추 가격:  [2582.2378]
# # 63000  손실 비용:  2247820.0
# - 배추 가격:  [2582.2715]
# # 63500  손실 비용:  2247554.2
# - 배추 가격:  [2582.305]
# # 64000  손실 비용:  2247288.8
# - 배추 가격:  [2582.3384]
# # 64500  손실 비용:  2247023.5
# - 배추 가격:  [2582.372]
# # 65000  손실 비용:  2246758.5
# - 배추 가격:  [2582.4058]
# # 65500  손실 비용:  2246493.2
# - 배추 가격:  [2582.4502]
# # 66000  손실 비용:  2246228.2
# - 배추 가격:  [2582.5015]
# # 66500  손실 비용:  2245963.2
# - 배추 가격:  [2582.5542]
# # 67000  손실 비용:  2245698.5
# - 배추 가격:  [2582.6082]
# # 67500  손실 비용:  2245433.8
# - 배추 가격:  [2582.6594]
# # 68000  손실 비용:  2245169.0
# - 배추 가격:  [2582.7102]
# # 68500  손실 비용:  2244904.8
# - 배추 가격:  [2582.7598]
# # 69000  손실 비용:  2244640.0
# - 배추 가격:  [2582.8052]
# # 69500  손실 비용:  2244376.0
# - 배추 가격:  [2582.8503]
# # 70000  손실 비용:  2244112.0
# - 배추 가격:  [2582.8943]
# # 70500  손실 비용:  2243848.0
# - 배추 가격:  [2582.9343]
# # 71000  손실 비용:  2243584.0
# - 배추 가격:  [2582.9685]
# # 71500  손실 비용:  2243320.2
# - 배추 가격:  [2583.0024]
# # 72000  손실 비용:  2243056.5
# - 배추 가격:  [2583.0361]
# # 72500  손실 비용:  2242793.2
# - 배추 가격:  [2583.0703]
# # 73000  손실 비용:  2242529.8
# - 배추 가격:  [2583.105]
# # 73500  손실 비용:  2242268.0
# - 배추 가격:  [2583.1357]
# # 74000  손실 비용:  2242006.8
# - 배추 가격:  [2583.1592]
# # 74500  손실 비용:  2241746.0
# - 배추 가격:  [2583.1812]
# # 75000  손실 비용:  2241485.8
# - 배추 가격:  [2583.2031]
# # 75500  손실 비용:  2241225.2
# - 배추 가격:  [2583.2253]
# # 76000  손실 비용:  2240964.5
# - 배추 가격:  [2583.2476]
# # 76500  손실 비용:  2240704.5
# - 배추 가격:  [2583.2683]
# # 77000  손실 비용:  2240444.2
# - 배추 가격:  [2583.285]
# # 77500  손실 비용:  2240184.2
# - 배추 가격:  [2583.3015]
# # 78000  손실 비용:  2239924.5
# - 배추 가격:  [2583.3184]
# # 78500  손실 비용:  2239664.5
# - 배추 가격:  [2583.3354]
# # 79000  손실 비용:  2239404.8
# - 배추 가격:  [2583.352]
# # 79500  손실 비용:  2239145.0
# - 배추 가격:  [2583.3687]
# # 80000  손실 비용:  2238885.5
# - 배추 가격:  [2583.3848]
# # 80500  손실 비용:  2238626.5
# - 배추 가격:  [2583.396]
# # 81000  손실 비용:  2238367.0
# - 배추 가격:  [2583.4075]
# # 81500  손실 비용:  2238107.8
# - 배추 가격:  [2583.419]
# # 82000  손실 비용:  2237848.5
# - 배추 가격:  [2583.4304]
# # 82500  손실 비용:  2237589.5
# - 배추 가격:  [2583.442]
# # 83000  손실 비용:  2237330.8
# - 배추 가격:  [2583.4531]
# # 83500  손실 비용:  2237071.8
# - 배추 가격:  [2583.4646]
# # 84000  손실 비용:  2236813.5
# - 배추 가격:  [2583.476]
# # 84500  손실 비용:  2236554.5
# - 배추 가격:  [2583.4878]
# # 85000  손실 비용:  2236296.2
# - 배추 가격:  [2583.497]
# # 85500  손실 비용:  2236037.5
# - 배추 가격:  [2583.5032]
# # 86000  손실 비용:  2235779.5
# - 배추 가격:  [2583.5093]
# # 86500  손실 비용:  2235520.8
# - 배추 가격:  [2583.5154]
# # 87000  손실 비용:  2235263.5
# - 배추 가격:  [2583.5215]
# # 87500  손실 비용:  2235005.5
# - 배추 가격:  [2583.5276]
# # 88000  손실 비용:  2234747.8
# - 배추 가격:  [2583.5437]
# # 88500  손실 비용:  2234489.8
# - 배추 가격:  [2583.578]
# # 89000  손실 비용:  2234232.5
# - 배추 가격:  [2583.6116]
# # 89500  손실 비용:  2233975.2
# - 배추 가격:  [2583.6465]
# # 90000  손실 비용:  2233717.8
# - 배추 가격:  [2583.681]
# # 90500  손실 비용:  2233460.8
# - 배추 가격:  [2583.7156]
# # 91000  손실 비용:  2233205.8
# - 배추 가격:  [2583.7488]
# # 91500  손실 비용:  2232951.5
# - 배추 가격:  [2583.7827]
# # 92000  손실 비용:  2232697.0
# - 배추 가격:  [2583.8162]
# # 92500  손실 비용:  2232442.8
# - 배추 가격:  [2583.8506]
# # 93000  손실 비용:  2232188.5
# - 배추 가격:  [2583.8848]
# # 93500  손실 비용:  2231934.8
# - 배추 가격:  [2583.9187]
# # 94000  손실 비용:  2231680.5
# - 배추 가격:  [2583.9526]
# # 94500  손실 비용:  2231426.2
# - 배추 가격:  [2583.9868]
# # 95000  손실 비용:  2231172.8
# - 배추 가격:  [2584.0208]
# # 95500  손실 비용:  2230919.2
# - 배추 가격:  [2584.0552]
# # 96000  손실 비용:  2230665.8
# - 배추 가격:  [2584.0886]
# # 96500  손실 비용:  2230412.2
# - 배추 가격:  [2584.1233]
# # 97000  손실 비용:  2230159.0
# - 배추 가격:  [2584.158]
# # 97500  손실 비용:  2229906.2
# - 배추 가격:  [2584.1921]
# # 98000  손실 비용:  2229653.2
# - 배추 가격:  [2584.227]
# # 98500  손실 비용:  2229400.5
# - 배추 가격:  [2584.2615]
# # 99000  손실 비용:  2229147.5
# - 배추 가격:  [2584.296]
# # 99500  손실 비용:  2228895.0
# - 배추 가격:  [2584.3308]
# # 100000  손실 비용:  2228642.0
# - 배추 가격:  [2584.3647]
# 학습된 모델을 저장했습니다.
